# %% [markdown]
# ##_______________________________ code 5 _______________________________##
#
# Reading files

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.patches import Patch
from matplotlib import font_manager
import numpy as np

#-----------------read files - all problem------------------------
##merged avg stdev and others - problem based
#drift type : gradual
file_path_merged_summary_grd = 'final results/merged_summary_grd.csv'
df_merged_summary_grd = pd.read_csv(file_path_merged_summary_grd)
#drift type : re-occurring
file_path_merged_summary_oc = 'final results/merged_summary_oc.csv'
df_merged_summary_oc = pd.read_csv(file_path_merged_summary_oc)
#drift type : sudden
file_path_merged_summary_sud = 'final results/merged_summary_sud.csv'
df_merged_summary_sud = pd.read_csv(file_path_merged_summary_sud)


##analyzed from merged file - mean count percent
#drift type : gradual
file_path_output_mean_count_percent_all_grd = 'final results/analysis/grd/output_mean_count_percent_all.csv'
df_output_mean_count_percent_all_grd = pd.read_csv(file_path_output_mean_count_percent_all_grd)
#drift type : re-occurring
file_path_output_mean_count_percent_all_oc = 'final results/analysis/occ/output_mean_count_percent_all.csv'
df_output_mean_count_percent_all_oc = pd.read_csv(file_path_output_mean_count_percent_all_oc)
#drift type : sudden
file_path_output_mean_count_percent_all_sud = 'final results/analysis/sudd/output_mean_count_percent_all.csv'
df_output_mean_count_percent_all_sud = pd.read_csv(file_path_output_mean_count_percent_all_sud)

#-----------------read files - domain------------------------
##analyzed from domain based file - avg count percent
#drift type : gradual
file_path_output_avg_count_percent_domain_grd = 'final results/analysis/grd/output_avg_count_percent_domain.csv'
df_output_avg_count_percent_domain_grd = pd.read_csv(file_path_output_avg_count_percent_domain_grd)
#drift type : re-occurring
file_path_output_avg_count_percent_domain_oc = 'final results/analysis/occ/output_avg_count_percent_domain.csv'
df_output_avg_count_percent_domain_oc = pd.read_csv(file_path_output_avg_count_percent_domain_oc)
#drift type : sudden
file_path_output_avg_count_percent_domain_sud = 'final results/analysis/sudd/output_avg_count_percent_domain.csv'
df_output_avg_count_percent_domain_sud = pd.read_csv(file_path_output_avg_count_percent_domain_sud)

##domain based file - mean stdev
#drift type : gradual
file_path_domain_based_mean_stdev_results_grd = 'final results/analysis/grd/domain_based_mean_stdev_results.csv'
df_domain_based_mean_stdev_results_grd = pd.read_csv(file_path_domain_based_mean_stdev_results_grd)
#drift type : re-occurring
file_path_domain_based_mean_stdev_results_oc = 'final results/analysis/occ/domain_based_mean_stdev_results.csv'
df_domain_based_mean_stdev_results_oc = pd.read_csv(file_path_domain_based_mean_stdev_results_oc)
#drift type : sudden
file_path_domain_based_mean_stdev_results_sud = 'final results/analysis/sudd/domain_based_mean_stdev_results.csv'
df_domain_based_mean_stdev_results_sud = pd.read_csv(file_path_domain_based_mean_stdev_results_sud)

# %%
font_sub = {'family':'serif','color':'black','fontsize':16}  #Font for the title of each sub-chart
font_title = {'family':'serif','color':'black','fontsize':24}  #General chart title font
font_props = font_manager.FontProperties(family='serif', style='normal', size=14)  #Chart description font (explanation box)
font_lable = {'family':'serif','color':'black','fontsize':16} #Label Fonts
font_pie = {'fontsize': 14}

# %%
plt.rcParams.update(plt.rcParamsDefault)

# %% [markdown]
# Mean and standard deviation of BACC, Recall, Precision
#
# for each domain in each of the 3 implementations
#
# (each type of drift plotted in separate graphs - all three drifts)

# %%
x_domain_name = df_domain_based_mean_stdev_results_grd['domain'].str.split('\\').str[-1]

bacc_domain_std_grd = df_domain_based_mean_stdev_results_grd['BACC average standard']
bacc_domain_not_grd = df_domain_based_mean_stdev_results_grd['BACC average not use']
bacc_domain_use_grd = df_domain_based_mean_stdev_results_grd['BACC average use']
bacc_stdev_domain_std_grd = df_domain_based_mean_stdev_results_grd['BACC average standard std']
bacc_stdev_domain_not_grd = df_domain_based_mean_stdev_results_grd['BACC average not use std']
bacc_stdev_domain_use_grd = df_domain_based_mean_stdev_results_grd['BACC average use std']

bacc_domain_std_sud = df_domain_based_mean_stdev_results_sud['BACC average standard']
bacc_domain_not_sud = df_domain_based_mean_stdev_results_sud['BACC average not use']
bacc_domain_use_sud = df_domain_based_mean_stdev_results_sud['BACC average use']
bacc_stdev_domain_std_sud = df_domain_based_mean_stdev_results_sud['BACC average standard std']
bacc_stdev_domain_not_sud = df_domain_based_mean_stdev_results_sud['BACC average not use std']
bacc_stdev_domain_use_sud = df_domain_based_mean_stdev_results_sud['BACC average use std']

bacc_domain_std_oc = df_domain_based_mean_stdev_results_oc['BACC average standard']
bacc_domain_not_oc = df_domain_based_mean_stdev_results_oc['BACC average not use']
bacc_domain_use_oc = df_domain_based_mean_stdev_results_oc['BACC average use']
bacc_stdev_domain_std_oc = df_domain_based_mean_stdev_results_oc['BACC average standard std']
bacc_stdev_domain_not_oc = df_domain_based_mean_stdev_results_oc['BACC average not use std']
bacc_stdev_domain_use_oc = df_domain_based_mean_stdev_results_oc['BACC average use std']
#-----------------------------------------------------------------

recall_domain_std_grd = df_domain_based_mean_stdev_results_grd['Recall average standard']
recall_domain_not_grd = df_domain_based_mean_stdev_results_grd['Recall average not use']
recall_domain_use_grd = df_domain_based_mean_stdev_results_grd['Recall average use']
recall_stdev_domain_std_grd = df_domain_based_mean_stdev_results_grd['Recall average standard std']
recall_stdev_domain_not_grd = df_domain_based_mean_stdev_results_grd['Recall average not use std']
recall_stdev_domain_use_grd = df_domain_based_mean_stdev_results_grd['Recall average use std']

recall_domain_std_sud = df_domain_based_mean_stdev_results_sud['Recall average standard']
recall_domain_not_sud = df_domain_based_mean_stdev_results_sud['Recall average not use']
recall_domain_use_sud = df_domain_based_mean_stdev_results_sud['Recall average use']
recall_stdev_domain_std_sud = df_domain_based_mean_stdev_results_sud['Recall average standard std']
recall_stdev_domain_not_sud = df_domain_based_mean_stdev_results_sud['Recall average not use std']
recall_stdev_domain_use_sud = df_domain_based_mean_stdev_results_sud['Recall average use std']

recall_domain_std_oc = df_domain_based_mean_stdev_results_oc['Recall average standard']
recall_domain_not_oc = df_domain_based_mean_stdev_results_oc['Recall average not use']
recall_domain_use_oc = df_domain_based_mean_stdev_results_oc['Recall average use']
recall_stdev_domain_std_oc = df_domain_based_mean_stdev_results_oc['Recall average standard std']
recall_stdev_domain_not_oc = df_domain_based_mean_stdev_results_oc['Recall average not use std']
recall_stdev_domain_use_oc = df_domain_based_mean_stdev_results_oc['Recall average use std']
#-----------------------------------------------------------------
#-----------------------------------------------------------------

precision_domain_std_grd = df_domain_based_mean_stdev_results_grd['Precision average standard']
precision_domain_not_grd = df_domain_based_mean_stdev_results_grd['Precision average not use']
precision_domain_use_grd = df_domain_based_mean_stdev_results_grd['Precision average use']
precision_stdev_domain_std_grd = df_domain_based_mean_stdev_results_grd['Precision average standard std']
precision_stdev_domain_not_grd = df_domain_based_mean_stdev_results_grd['Precision average not use std']
precision_stdev_domain_use_grd = df_domain_based_mean_stdev_results_grd['Precision average use std']

precision_domain_std_sud = df_domain_based_mean_stdev_results_sud['Precision average standard']
precision_domain_not_sud = df_domain_based_mean_stdev_results_sud['Precision average not use']
precision_domain_use_sud = df_domain_based_mean_stdev_results_sud['Precision average use']
precision_stdev_domain_std_sud = df_domain_based_mean_stdev_results_sud['Precision average standard std']
precision_stdev_domain_not_sud = df_domain_based_mean_stdev_results_sud['Precision average not use std']
precision_stdev_domain_use_sud = df_domain_based_mean_stdev_results_sud['Precision average use std']

precision_domain_std_oc = df_domain_based_mean_stdev_results_oc['Precision average standard']
precision_domain_not_oc = df_domain_based_mean_stdev_results_oc['Precision average not use']
precision_domain_use_oc = df_domain_based_mean_stdev_results_oc['Precision average use']
precision_stdev_domain_std_oc = df_domain_based_mean_stdev_results_oc['Precision average standard std']
precision_stdev_domain_not_oc = df_domain_based_mean_stdev_results_oc['Precision average not use std']
precision_stdev_domain_use_oc = df_domain_based_mean_stdev_results_oc['Precision average use std']

# #--------------bacc - gradual-------------

#------------------

x = np.arange(len(x_domain_name))
width = 0.25

plt.figure(figsize=(15, 7))

plt.bar(x - width, bacc_domain_std_grd, width=width, label='Standard', color='skyblue')
plt.bar(x, bacc_domain_not_grd, width=width, label='without technique', color='salmon')
plt.bar(x + width, bacc_domain_use_grd, width=width, label='with technique', color='limegreen')

plt.xticks(x, x_domain_name , fontsize=16 , rotation=90)
plt.xlabel('Domain name' , fontdict= font_lable)
plt.ylabel('avg BACC' , fontdict= font_lable)

plt.yticks(fontsize=14)
plt.title('Comparison of BACC per Domain in Gradual Drift' , fontdict= font_title)
plt.legend(prop = font_props)
plt.tight_layout()

#------------------

plt.figure(figsize=(15, 8))

plt.errorbar(x - width, bacc_domain_std_grd, label='Standard', yerr= bacc_stdev_domain_std_grd , color='skyblue' , marker = 'o' , linestyle='none', ms = 16)
plt.errorbar(x, bacc_domain_not_grd, label='without technique', yerr= bacc_stdev_domain_not_grd , color='salmon' , marker='x' , linestyle='none' , ms = 16)
plt.errorbar(x + width, bacc_domain_use_grd, label='with technique', yerr= bacc_stdev_domain_use_grd , color='limegreen', marker='*', linestyle='none' , ms = 16)

plt.xticks(x, x_domain_name, fontsize=14 , rotation=90)
plt.xlabel('Domain name' , fontdict= font_lable)
plt.ylabel('avg BACC' , fontdict= font_lable)

plt.yticks(fontsize=14)
plt.title('Comparison of BACC per Domain in Gradual Drift' , fontdict= font_title)
plt.legend(prop = font_props)
plt.tight_layout()


# #--------------bacc - re-occurring-------------

plt.figure(figsize=(15, 7))

plt.bar(x - width, bacc_domain_std_oc, width=width, label='Standard', color='skyblue')
plt.bar(x, bacc_domain_not_oc, width=width, label='without technique', color='salmon')
plt.bar(x + width, bacc_domain_use_oc, width=width, label='with technique', color='limegreen')

plt.xticks(x, x_domain_name , fontsize=16 , rotation=90)
plt.xlabel('Domain name' , fontdict= font_lable)
plt.ylabel('avg BACC' , fontdict= font_lable)
plt.yticks(fontsize=14)
plt.title('Comparison of BACC per Domain in Re-occurring Drift' , fontdict= font_title)
plt.legend(prop = font_props)
plt.tight_layout()

#------------------
plt.figure(figsize=(15, 8))

plt.errorbar(x - width, bacc_domain_std_oc, label='Standard', yerr= bacc_stdev_domain_std_oc , color='skyblue' , marker = 'o' , linestyle='none' , ms = 16)
plt.errorbar(x, bacc_domain_not_oc, label='without technique', yerr= bacc_stdev_domain_not_oc , color='salmon' , marker='x' , linestyle='none' , ms = 16)
plt.errorbar(x + width, bacc_domain_use_oc, label='with technique', yerr= bacc_stdev_domain_use_oc , color='limegreen', marker='*', linestyle='none' , ms = 16)

plt.xticks(x, x_domain_name , fontsize = 14 , rotation = 90)
plt.xlabel('Domain name' , fontdict= font_lable)
plt.ylabel('avg BACC' , fontdict= font_lable)
plt.yticks(fontsize=14)
plt.title('Comparison of BACC per Domain in Re-occurring Drift' , fontdict= font_title)
plt.legend(prop = font_props)
plt.tight_layout()


# #--------------bacc - sudden-------------

plt.figure(figsize=(15, 7))

plt.bar(x - width, bacc_domain_std_sud, width=width, label='Standard', color='skyblue')
plt.bar(x, bacc_domain_not_sud, width=width, label='without technique', color='salmon')
plt.bar(x + width, bacc_domain_use_sud, width=width, label='with technique', color='limegreen')

plt.xticks(x, x_domain_name , fontsize=16 , rotation=90)
plt.xlabel('Domain name' , fontdict= font_lable)
plt.ylabel('avg BACC' , fontdict= font_lable)
plt.yticks(fontsize=14)
plt.title('Comparison of BACC per Domain in Sudden Drift' , fontdict= font_title)
plt.legend(prop = font_props)
plt.tight_layout()

#------------------
plt.figure(figsize=(15, 8))

plt.errorbar(x - width, bacc_domain_std_sud, label='Standard', yerr= bacc_stdev_domain_std_sud , color='skyblue' , marker = 'o' , linestyle='none' , ms = 16)
plt.errorbar(x, bacc_domain_not_sud, label='without technique', yerr= bacc_stdev_domain_not_sud , color='salmon' , marker='x' , linestyle='none' , ms = 16)
plt.errorbar(x + width, bacc_domain_use_sud, label='with technique', yerr= bacc_stdev_domain_use_sud , color='limegreen', marker='*', linestyle='none' , ms = 16)

plt.xticks(x, x_domain_name , fontsize=16 , rotation=90)
plt.xlabel('Domain name' , fontdict= font_lable)
plt.ylabel('avg BACC' , fontdict= font_lable)
plt.yticks(fontsize=14)
plt.title('Comparison of BACC per Domain in Sudden Drift' , fontdict= font_title)
plt.legend(prop = font_props)
plt.tight_layout()



# #--------------recall - gradual-------------

plt.figure(figsize=(15, 7))

plt.bar(x - width, recall_domain_std_grd, width=width, label='Standard', color='skyblue')
plt.bar(x, recall_domain_not_grd, width=width, label='without technique', color='salmon')
plt.bar(x + width, recall_domain_use_grd, width=width, label='with technique', color='limegreen')

plt.xticks(x, x_domain_name , fontsize=16 , rotation=90)
plt.xlabel('Domain name' , fontdict= font_lable)
plt.ylabel('avg recall' , fontdict= font_lable)
plt.yticks(fontsize=14)
plt.title('Comparison of recall per Domain in Gradual Drift' , fontdict= font_title)
plt.legend(prop = font_props)
plt.tight_layout()

#------------------

plt.figure(figsize=(15, 8))

plt.errorbar(x - width, recall_domain_std_grd, label='Standard', yerr= recall_stdev_domain_std_grd , color='skyblue' , marker = 'o' , linestyle='none' , ms = 16)
plt.errorbar(x, recall_domain_not_grd, label='without technique', yerr= recall_stdev_domain_not_grd , color='salmon' , marker='x' , linestyle='none' , ms = 16)
plt.errorbar(x + width, recall_domain_use_grd, label='with technique', yerr= recall_stdev_domain_use_grd , color='limegreen', marker='*', linestyle='none' , ms = 16)

plt.xticks(x, x_domain_name , fontsize=16 , rotation=90)
plt.xlabel('Domain name' , fontdict= font_lable)
plt.ylabel('avg recall' , fontdict= font_lable)
plt.yticks(fontsize=14)
plt.title('Comparison of recall per Domain in Gradual Drift' , fontdict= font_title)
plt.legend(prop = font_props)
plt.tight_layout()


# #--------------recall - re-occurring-------------

plt.figure(figsize=(15, 7))

plt.bar(x - width, recall_domain_std_oc, width=width, label='Standard', color='skyblue')
plt.bar(x, recall_domain_not_oc, width=width, label='without technique', color='salmon')
plt.bar(x + width, recall_domain_use_oc, width=width, label='with technique', color='limegreen')

plt.xticks(x, x_domain_name , fontsize=16 , rotation=90)
plt.xlabel('Domain name' , fontdict= font_lable)
plt.ylabel('avg recall' , fontdict= font_lable)
plt.yticks(fontsize=14)
plt.title('Comparison of recall per Domain in Re-occurring Drift' , fontdict= font_title)
plt.legend(prop = font_props)
plt.tight_layout()

#------------------
plt.figure(figsize=(15, 8))

plt.errorbar(x - width, recall_domain_std_oc, label='Standard', yerr= recall_stdev_domain_std_oc , color='skyblue' , marker = 'o' , linestyle='none' , ms = 16)
plt.errorbar(x, recall_domain_not_oc, label='without technique', yerr= recall_stdev_domain_not_oc , color='salmon' , marker='x' , linestyle='none' , ms = 16)
plt.errorbar(x + width, recall_domain_use_oc, label='with technique', yerr= recall_stdev_domain_use_oc , color='limegreen', marker='*', linestyle='none' , ms = 16)

plt.xticks(x, x_domain_name , fontsize=16 , rotation=90)
plt.xlabel('Domain name' , fontdict= font_lable)
plt.ylabel('avg recall' , fontdict= font_lable)
plt.yticks(fontsize=14)
plt.title('Comparison of recall per Domain in Re-occurring Drift' , fontdict= font_title)
plt.legend(prop = font_props)
plt.tight_layout()


# #--------------recall - sudden-------------

plt.figure(figsize=(15, 7))

plt.bar(x - width, recall_domain_std_sud, width=width, label='Standard', color='skyblue')
plt.bar(x, recall_domain_not_sud, width=width, label='without technique', color='salmon')
plt.bar(x + width, recall_domain_use_sud, width=width, label='with technique', color='limegreen')

plt.xticks(x, x_domain_name , fontsize=16 , rotation=90)
plt.xlabel('Domain name' , fontdict= font_lable)
plt.ylabel('avg recall' , fontdict= font_lable)
plt.yticks(fontsize=14)
plt.title('Comparison of recall per Domain in Sudden Drift' , fontdict= font_title)
plt.legend(prop = font_props)
plt.tight_layout()

#------------------
plt.figure(figsize=(15, 8))

plt.errorbar(x - width, recall_domain_std_sud, label='Standard', yerr= recall_stdev_domain_std_sud , color='skyblue' , marker = 'o' , linestyle='none' , ms = 16)
plt.errorbar(x, recall_domain_not_sud, label='without technique', yerr= recall_stdev_domain_not_sud , color='salmon' , marker='x' , linestyle='none' , ms = 16)
plt.errorbar(x + width, recall_domain_use_sud, label='with technique', yerr= recall_stdev_domain_use_sud , color='limegreen', marker='*', linestyle='none' , ms = 16)

plt.xticks(x, x_domain_name , fontsize=16 , rotation=90)
plt.xlabel('Domain name' , fontdict= font_lable)
plt.ylabel('avg recall' , fontdict= font_lable)
plt.yticks(fontsize=14)
plt.title('Comparison of recall per Domain in Sudden Drift' , fontdict= font_title)
plt.legend(prop = font_props)
plt.tight_layout()


# #--------------precision - gradual-------------

plt.figure(figsize=(15, 7))

plt.bar(x - width, precision_domain_std_grd, width=width, label='Standard', color='skyblue')
plt.bar(x, precision_domain_not_grd, width=width, label='without technique', color='salmon')
plt.bar(x + width, precision_domain_use_grd, width=width, label='with technique', color='limegreen')

plt.xticks(x, x_domain_name , fontsize=16 , rotation=90)
plt.xlabel('Domain name' , fontdict= font_lable)
plt.ylabel('avg precision' , fontdict= font_lable)
plt.yticks(fontsize=14)
plt.title('Comparison of precision per Domain in Gradual Drift' , fontdict= font_title)
plt.legend(prop = font_props)
plt.tight_layout()

#------------------

plt.figure(figsize=(15, 8))

plt.errorbar(x - width, precision_domain_std_grd, label='Standard', yerr= precision_stdev_domain_std_grd , color='skyblue' , marker = 'o' , linestyle='none' , ms = 16)
plt.errorbar(x, precision_domain_not_grd, label='without technique', yerr= precision_stdev_domain_not_grd , color='salmon' , marker='x' , linestyle='none' , ms = 16)
plt.errorbar(x + width, precision_domain_use_grd, label='with technique', yerr= precision_stdev_domain_use_grd , color='limegreen', marker='*', linestyle='none' , ms = 16)

plt.xticks(x, x_domain_name , fontsize=16 , rotation=90)
plt.xlabel('Domain name' , fontdict= font_lable)
plt.ylabel('avg precision' , fontdict= font_lable)
plt.yticks(fontsize=14)
plt.title('Comparison of precision per Domain in Gradual Drift' , fontdict= font_title)
plt.legend(prop = font_props)
plt.tight_layout()


# #--------------precision - re-occurring-------------

plt.figure(figsize=(15, 7))

plt.bar(x - width, precision_domain_std_oc, width=width, label='Standard', color='skyblue')
plt.bar(x, precision_domain_not_oc, width=width, label='without technique', color='salmon')
plt.bar(x + width, precision_domain_use_oc, width=width, label='with technique', color='limegreen')

plt.xticks(x, x_domain_name , fontsize=16 , rotation=90)
plt.xlabel('Domain name' , fontdict= font_lable)
plt.ylabel('avg precision' , fontdict= font_lable)
plt.yticks(fontsize=14)
plt.title('Comparison of precision per Domain in Re-occurring Drift' , fontdict= font_title)
plt.legend(prop = font_props)
plt.tight_layout()

#------------------
plt.figure(figsize=(15, 8))

# رسم ستون‌ها با فاصله مشخص کنار هم
plt.errorbar(x - width, precision_domain_std_oc, label='Standard', yerr= precision_stdev_domain_std_oc , color='skyblue' , marker = 'o' , linestyle='none' , ms = 16)
plt.errorbar(x, precision_domain_not_oc, label='without technique', yerr= precision_stdev_domain_not_oc , color='salmon' , marker='x' , linestyle='none' , ms = 16)
plt.errorbar(x + width, precision_domain_use_oc, label='with technique', yerr= precision_stdev_domain_use_oc , color='limegreen', marker='*', linestyle='none' , ms = 16)

plt.xticks(x, x_domain_name , fontsize=16 , rotation=90)
plt.xlabel('Domain name' , fontdict= font_lable)
plt.ylabel('avg precision' , fontdict= font_lable)
plt.yticks(fontsize=14)
plt.title('Comparison of precision per Domain in Re-occurring Drift' , fontdict= font_title)
plt.legend(prop = font_props)
plt.tight_layout()


# #--------------precision - sudden-------------

plt.figure(figsize=(15, 7))

plt.bar(x - width, precision_domain_std_sud, width=width, label='Standard', color='skyblue')
plt.bar(x, precision_domain_not_sud, width=width, label='without technique', color='salmon')
plt.bar(x + width, precision_domain_use_sud, width=width, label='with technique', color='limegreen')

plt.xticks(x, x_domain_name , fontsize=16 , rotation=90)
plt.xlabel('Domain name' , fontdict= font_lable)
plt.ylabel('avg precision' , fontdict= font_lable)
plt.yticks(fontsize=14)
plt.title('Comparison of precision per Domain in Sudden Drift' , fontdict= font_title)
plt.legend(prop = font_props)
plt.tight_layout()

#------------------
plt.figure(figsize=(15, 8))

plt.errorbar(x - width, precision_domain_std_sud, label='Standard', yerr= precision_stdev_domain_std_sud , color='skyblue' , marker = 'o' , linestyle='none' , ms = 16)
plt.errorbar(x, precision_domain_not_sud, label='without technique', yerr= precision_stdev_domain_not_sud , color='salmon' , marker='x' , linestyle='none' , ms = 16)
plt.errorbar(x + width, precision_domain_use_sud, label='with technique', yerr= precision_stdev_domain_use_sud , color='limegreen', marker='*', linestyle='none' , ms = 16)

plt.xticks(x, x_domain_name , fontsize=16 , rotation=90)
plt.xlabel('Domain name' , fontdict= font_lable)
plt.ylabel('avg precision' , fontdict= font_lable)
plt.yticks(fontsize=14)
plt.title('Comparison of precision per Domain in Sudden Drift' , fontdict= font_title)
plt.legend(prop = font_props)
plt.tight_layout()


plt.show()

# %% [markdown]
# Percentage of improvement, drop, and no change in three metrics
# (problem-based and domain-based)
# in three drifts

# %%
#--initial option
labels = ['Improvement' , 'Drop' , 'No change']
# colors = ["hotpink" , "black"]
colors = ["DarkSeaGreen" , "IndianRed" , "CornflowerBlue"]



#===============================problem based=====================================#
#------------------BACC percent - problems-----------------------------
bacc_imp_per = df_output_mean_count_percent_all_grd['BACC improvement percent']
bacc_imp_per = float(bacc_imp_per.iloc[0])

bacc_drop_per = df_output_mean_count_percent_all_grd['BACC DROP percent']
bacc_drop_per = float(bacc_drop_per.iloc[0])

bacc_no_change_per = df_output_mean_count_percent_all_grd['BACC no change percent']
bacc_no_change_per = float(bacc_no_change_per.iloc[0])

bacc_pie_array_all = np.array([bacc_imp_per , bacc_drop_per , bacc_no_change_per])

#------------------recall percent - problems-----------------------------
recall_imp_per = df_output_mean_count_percent_all_grd['Recall improvement percent']
recall_imp_per = float(recall_imp_per.iloc[0])

recall_drop_per = df_output_mean_count_percent_all_grd['Recall DROP percent']
recall_drop_per = float(recall_drop_per.iloc[0])

recall_no_change_per = df_output_mean_count_percent_all_grd['Recall no change percent']
recall_no_change_per = float(recall_no_change_per.iloc[0])

recall_pie_array_all = np.array([recall_imp_per , recall_drop_per , recall_no_change_per])

#------------------precision percent - problems-----------------------------
precision_imp_per = df_output_mean_count_percent_all_grd['precision improvement percent']
precision_imp_per = float(precision_imp_per.iloc[0])

precision_drop_per = df_output_mean_count_percent_all_grd['precision drop percent']
precision_drop_per = float(precision_drop_per.iloc[0])

precision_no_change_per = df_output_mean_count_percent_all_grd['precision no change percent']
precision_no_change_per = float(precision_no_change_per.iloc[0])

precision_pie_array_all = np.array([precision_imp_per , precision_drop_per , precision_no_change_per])

#============sub plot===============
plt.figure(figsize=(15, 5))

# plt.subplot(2,2,1)
plt.subplot(1,3,1)

plt.pie(bacc_pie_array_all ,labels=None , autopct='%1.2f%%' , colors= colors , textprops=font_pie)

plt.title("BACC" , fontdict=font_sub)

plt.subplot(1,3,2)
plt.pie(recall_pie_array_all ,labels=None , autopct='%1.2f%%' , colors= colors , textprops=font_pie)
plt.title("Recall" , fontdict=font_sub)

plt.subplot(1,3,3)

plt.pie(precision_pie_array_all ,labels=None , autopct='%1.2f%%' , colors= colors , textprops=font_pie)

plt.title("Precision" , fontdict=font_sub)

plt.legend(labels , loc = 'lower right'  , prop = font_props)

plt.suptitle("No change, Improvement and Drop percent over problems - gradual drift" , fontdict = font_title)
plt.show()


#===============================domain based=====================================#
#------------------BACC percent - domains-----------------------------
bacc_imp_per = df_output_avg_count_percent_domain_grd['bacc improvement percent']
bacc_imp_per = float(bacc_imp_per.iloc[0])

bacc_drop_per = df_output_avg_count_percent_domain_grd['bacc drop percent']
bacc_drop_per = float(bacc_drop_per.iloc[0])

bacc_no_change_per = df_output_avg_count_percent_domain_grd['bacc no change percent']
bacc_no_change_per = float(bacc_no_change_per.iloc[0])

bacc_pie_array_all = np.array([bacc_imp_per , bacc_drop_per , bacc_no_change_per])

#------------------recall percent - domains-----------------------------
recall_imp_per = df_output_avg_count_percent_domain_grd['recall improvement percent']
recall_imp_per = float(recall_imp_per.iloc[0])

recall_drop_per = df_output_avg_count_percent_domain_grd['recall drop percent']
recall_drop_per = float(recall_drop_per.iloc[0])

recall_no_change_per = df_output_avg_count_percent_domain_grd['recall no change percent']
recall_no_change_per = float(recall_no_change_per.iloc[0])

recall_pie_array_all = np.array([recall_imp_per , recall_drop_per , recall_no_change_per])

#------------------precision percent - domains-----------------------------
precision_imp_per = df_output_avg_count_percent_domain_grd['precision improvement percent']
precision_imp_per = float(precision_imp_per.iloc[0])

precision_drop_per = df_output_avg_count_percent_domain_grd['precision drop percent']
precision_drop_per = float(precision_drop_per.iloc[0])

precision_no_change_per = df_output_avg_count_percent_domain_grd['precision no change percent']
precision_no_change_per = float(precision_no_change_per.iloc[0])

precision_pie_array_all = np.array([precision_imp_per , precision_drop_per , precision_no_change_per])

#============sub plot===============
plt.figure(figsize=(15, 5))
plt.subplot(1,3,1)
plt.pie(bacc_pie_array_all ,labels=None , autopct='%1.2f%%' , colors= colors , textprops=font_pie)
plt.title("BACC" , fontdict=font_sub)

plt.subplot(1,3,2)
plt.pie(recall_pie_array_all ,labels=None , autopct='%1.2f%%' , colors= colors , textprops=font_pie)
plt.title("Recall" , fontdict=font_sub)

plt.subplot(1,3,3)

plt.pie(precision_pie_array_all ,labels=None , autopct='%1.2f%%' , colors= colors , textprops=font_pie)

plt.title("Precision" , fontdict=font_sub)

plt.legend(labels , loc = 'lower right'  , prop = font_props)

plt.suptitle("No change, Improvement and Drop percent over domains - gradual drift" , fontdict = font_title)
##@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@##


#===============================problem based=====================================#
#------------------BACC percent - problems-----------------------------
bacc_imp_per = df_output_mean_count_percent_all_oc['BACC improvement percent']
bacc_imp_per = float(bacc_imp_per.iloc[0])

bacc_drop_per = df_output_mean_count_percent_all_oc['BACC DROP percent']
bacc_drop_per = float(bacc_drop_per.iloc[0])

bacc_no_change_per = df_output_mean_count_percent_all_oc['BACC no change percent']
bacc_no_change_per = float(bacc_no_change_per.iloc[0])

bacc_pie_array_all = np.array([bacc_imp_per , bacc_drop_per , bacc_no_change_per])

#------------------recall percent - problems-----------------------------
recall_imp_per = df_output_mean_count_percent_all_oc['Recall improvement percent']
recall_imp_per = float(recall_imp_per.iloc[0])

recall_drop_per = df_output_mean_count_percent_all_oc['Recall DROP percent']
recall_drop_per = float(recall_drop_per.iloc[0])

recall_no_change_per = df_output_mean_count_percent_all_oc['Recall no change percent']
recall_no_change_per = float(recall_no_change_per.iloc[0])

recall_pie_array_all = np.array([recall_imp_per , recall_drop_per , recall_no_change_per])


#------------------precision percent - problems-----------------------------
precision_imp_per = df_output_mean_count_percent_all_oc['precision improvement percent']
precision_imp_per = float(precision_imp_per.iloc[0])

precision_drop_per = df_output_mean_count_percent_all_oc['precision drop percent']
precision_drop_per = float(precision_drop_per.iloc[0])

precision_no_change_per = df_output_mean_count_percent_all_oc['precision no change percent']
precision_no_change_per = float(precision_no_change_per.iloc[0])

precision_pie_array_all = np.array([precision_imp_per , precision_drop_per , precision_no_change_per])


#============sub plot===============
plt.figure(figsize=(15, 5))

plt.subplot(1,3,1)
plt.pie(bacc_pie_array_all ,labels=None , autopct='%1.2f%%' , colors= colors , textprops=font_pie)

plt.title("BACC" , fontdict=font_sub)


plt.subplot(1,3,2)
plt.pie(recall_pie_array_all ,labels=None , autopct='%1.2f%%' , colors= colors , textprops=font_pie)
plt.title("Recall" , fontdict=font_sub)

plt.subplot(1,3,3)

plt.pie(precision_pie_array_all ,labels=None , autopct='%1.2f%%' , colors= colors , textprops=font_pie)

plt.title("Precision" , fontdict=font_sub)

plt.legend(labels , loc = 'lower right'  , prop = font_props)

plt.suptitle("No change, Improvement and Drop percent over problems - re-occurring drift" , fontdict = font_title)
plt.show()

#===============================domain based=====================================#
#------------------BACC percent - domains-----------------------------
bacc_imp_per = df_output_avg_count_percent_domain_oc['bacc improvement percent']
bacc_imp_per = float(bacc_imp_per.iloc[0])

bacc_drop_per = df_output_avg_count_percent_domain_oc['bacc drop percent']
bacc_drop_per = float(bacc_drop_per.iloc[0])

bacc_no_change_per = df_output_avg_count_percent_domain_oc['bacc no change percent']
bacc_no_change_per = float(bacc_no_change_per.iloc[0])

bacc_pie_array_all = np.array([bacc_imp_per , bacc_drop_per , bacc_no_change_per])

#------------------recall percent - domains-----------------------------
recall_imp_per = df_output_avg_count_percent_domain_oc['recall improvement percent']
recall_imp_per = float(recall_imp_per.iloc[0])

recall_drop_per = df_output_avg_count_percent_domain_oc['recall drop percent']
recall_drop_per = float(recall_drop_per.iloc[0])

recall_no_change_per = df_output_avg_count_percent_domain_oc['recall no change percent']
recall_no_change_per = float(recall_no_change_per.iloc[0])

recall_pie_array_all = np.array([recall_imp_per , recall_drop_per , recall_no_change_per])

#------------------precision percent - domains-----------------------------
precision_imp_per = df_output_avg_count_percent_domain_oc['precision improvement percent']
precision_imp_per = float(precision_imp_per.iloc[0])

precision_drop_per = df_output_avg_count_percent_domain_oc['precision drop percent']
precision_drop_per = float(precision_drop_per.iloc[0])

precision_no_change_per = df_output_avg_count_percent_domain_oc['precision no change percent']
precision_no_change_per = float(precision_no_change_per.iloc[0])

precision_pie_array_all = np.array([precision_imp_per , precision_drop_per , precision_no_change_per])

#============sub plot===============
plt.figure(figsize=(15, 5))

plt.subplot(1,3,1)
plt.pie(bacc_pie_array_all ,labels=None , autopct='%1.2f%%' , colors= colors , textprops=font_pie)
plt.title("BACC" , fontdict=font_sub)

plt.subplot(1,3,2)
plt.pie(recall_pie_array_all ,labels=None , autopct='%1.2f%%' , colors= colors , textprops=font_pie)

plt.title("Recall" , fontdict=font_sub)

plt.subplot(1,3,3)

plt.pie(precision_pie_array_all ,labels=None , autopct='%1.2f%%' , colors= colors , textprops=font_pie)

plt.title("Precision" , fontdict=font_sub)

plt.legend(labels , loc = 'lower right'  , prop = font_props)

plt.suptitle("No change, Improvement and Drop percent over domains - re-occurring drift" , fontdict = font_title)
##@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@##


#===============================problem based=====================================#
#------------------BACC percent - problems-----------------------------
bacc_imp_per = df_output_mean_count_percent_all_sud['BACC improvement percent']
bacc_imp_per = float(bacc_imp_per.iloc[0])

bacc_drop_per = df_output_mean_count_percent_all_sud['BACC DROP percent']
bacc_drop_per = float(bacc_drop_per.iloc[0])

bacc_no_change_per = df_output_mean_count_percent_all_sud['BACC no change percent']
bacc_no_change_per = float(bacc_no_change_per.iloc[0])

bacc_pie_array_all = np.array([bacc_imp_per , bacc_drop_per , bacc_no_change_per])

#------------------recall percent - problems-----------------------------
recall_imp_per = df_output_mean_count_percent_all_sud['Recall improvement percent']
recall_imp_per = float(recall_imp_per.iloc[0])

recall_drop_per = df_output_mean_count_percent_all_sud['Recall DROP percent']
recall_drop_per = float(recall_drop_per.iloc[0])

recall_no_change_per = df_output_mean_count_percent_all_sud['Recall no change percent']
recall_no_change_per = float(recall_no_change_per.iloc[0])

recall_pie_array_all = np.array([recall_imp_per , recall_drop_per , recall_no_change_per])

#------------------precision percent - problems-----------------------------
precision_imp_per = df_output_mean_count_percent_all_sud['precision improvement percent']
precision_imp_per = float(precision_imp_per.iloc[0])

precision_drop_per = df_output_mean_count_percent_all_sud['precision drop percent']
precision_drop_per = float(precision_drop_per.iloc[0])

precision_no_change_per = df_output_mean_count_percent_all_sud['precision no change percent']
precision_no_change_per = float(precision_no_change_per.iloc[0])

precision_pie_array_all = np.array([precision_imp_per , precision_drop_per , precision_no_change_per])


#============sub plot===============

plt.figure(figsize=(15, 5))


plt.subplot(1,3,1)
plt.pie(bacc_pie_array_all ,labels=None , autopct='%1.2f%%' , colors= colors , textprops=font_pie)

plt.title("BACC" , fontdict=font_sub)

plt.subplot(1,3,2)
plt.pie(recall_pie_array_all ,labels=None , autopct='%1.2f%%' , colors= colors , textprops=font_pie)

plt.title("Recall" , fontdict=font_sub)

plt.subplot(1,3,3)

plt.pie(precision_pie_array_all ,labels=None , autopct='%1.2f%%' , colors= colors , textprops=font_pie)

plt.title("Precision" , fontdict=font_sub)

plt.legend(labels , loc = 'lower right'  , prop = font_props)

plt.suptitle("No change, Improvement and Drop percent over problems - sudden drift" , fontdict = font_title)
plt.show()

#===============================domain based=====================================#
#------------------BACC percent - domains-----------------------------
bacc_imp_per = df_output_avg_count_percent_domain_sud['bacc improvement percent']
bacc_imp_per = float(bacc_imp_per.iloc[0])

bacc_drop_per = df_output_avg_count_percent_domain_sud['bacc drop percent']
bacc_drop_per = float(bacc_drop_per.iloc[0])

bacc_no_change_per = df_output_avg_count_percent_domain_sud['bacc no change percent']
bacc_no_change_per = float(bacc_no_change_per.iloc[0])

bacc_pie_array_all = np.array([bacc_imp_per , bacc_drop_per , bacc_no_change_per])

#------------------recall percent - domains-----------------------------
recall_imp_per = df_output_avg_count_percent_domain_sud['recall improvement percent']
recall_imp_per = float(recall_imp_per.iloc[0])

recall_drop_per = df_output_avg_count_percent_domain_sud['recall drop percent']
recall_drop_per = float(recall_drop_per.iloc[0])

recall_no_change_per = df_output_avg_count_percent_domain_sud['recall no change percent']
recall_no_change_per = float(recall_no_change_per.iloc[0])

recall_pie_array_all = np.array([recall_imp_per , recall_drop_per , recall_no_change_per])


#------------------precision percent - domains-----------------------------
precision_imp_per = df_output_avg_count_percent_domain_sud['precision improvement percent']
precision_imp_per = float(precision_imp_per.iloc[0])

precision_drop_per = df_output_avg_count_percent_domain_sud['precision drop percent']
precision_drop_per = float(precision_drop_per.iloc[0])

precision_no_change_per = df_output_avg_count_percent_domain_sud['precision no change percent']
precision_no_change_per = float(precision_no_change_per.iloc[0])

precision_pie_array_all = np.array([precision_imp_per , precision_drop_per , precision_no_change_per])

#============sub plot===============

plt.figure(figsize=(15, 5))

plt.subplot(1,3,1)
plt.pie(bacc_pie_array_all ,labels=None , autopct='%1.2f%%' , colors= colors , textprops=font_pie)

plt.title("BACC" , fontdict=font_sub)

plt.subplot(1,3,2)
plt.pie(recall_pie_array_all ,labels=None , autopct='%1.2f%%' , colors= colors , textprops=font_pie)

plt.title("Recall" , fontdict=font_sub)

plt.subplot(1,3,3)

plt.pie(precision_pie_array_all ,labels=None , autopct='%1.2f%%' , colors= colors , textprops=font_pie)

plt.title("Precision" , fontdict=font_sub)

plt.legend(labels , loc = 'lower right'  , prop = font_props)

plt.suptitle("No change, Improvement and Drop percent over domains - sudden drift" , fontdict = font_title)
plt.show()

# %% [markdown]
# Average of three metrics for three types of systems in three drifts

# %%
bacc_avg_std_grd = df_merged_summary_grd['BACC average standard'].mean()
bacc_avg_not_grd = df_merged_summary_grd['BACC average not use'].mean()
bacc_avg_use_grd = df_merged_summary_grd['BACC average use'].mean()

bacc_avg_std_sud = df_merged_summary_sud['BACC average standard'].mean()
bacc_avg_not_sud = df_merged_summary_sud['BACC average not use'].mean()
bacc_avg_use_sud = df_merged_summary_sud['BACC average use'].mean()

bacc_avg_std_oc = df_merged_summary_oc['BACC average standard'].mean()
bacc_avg_not_oc = df_merged_summary_oc['BACC average not use'].mean()
bacc_avg_use_oc = df_merged_summary_oc['BACC average use'].mean()
#-----------------------------------------------------------------

recall_avg_std_grd = df_merged_summary_grd['Recall average standard'].mean()
recall_avg_not_grd = df_merged_summary_grd['Recall average not use'].mean()
recall_avg_use_grd = df_merged_summary_grd['Recall average use'].mean()

recall_avg_std_sud = df_merged_summary_sud['Recall average standard'].mean()
recall_avg_not_sud = df_merged_summary_sud['Recall average not use'].mean()
recall_avg_use_sud = df_merged_summary_sud['Recall average use'].mean()

recall_avg_std_oc = df_merged_summary_oc['Recall average standard'].mean()
recall_avg_not_oc = df_merged_summary_oc['Recall average not use'].mean()
recall_avg_use_oc = df_merged_summary_oc['Recall average use'].mean()
#-----------------------------------------------------------------
#-----------------------------------------------------------------

precision_avg_std_grd = df_merged_summary_grd['Precision average standard'].mean()
precision_avg_not_grd = df_merged_summary_grd['Precision average not use'].mean()
precision_avg_use_grd = df_merged_summary_grd['Precision average use'].mean()

precision_avg_std_sud = df_merged_summary_sud['Precision average standard'].mean()
precision_avg_not_sud = df_merged_summary_sud['Precision average not use'].mean()
precision_avg_use_sud = df_merged_summary_sud['Precision average use'].mean()

precision_avg_std_oc = df_merged_summary_oc['Precision average standard'].mean()
precision_avg_not_oc = df_merged_summary_oc['Precision average not use'].mean()
precision_avg_use_oc = df_merged_summary_oc['Precision average use'].mean()
#-----------------------------------------------------------------

x_sys_name = ['standard' , 'without technique' , 'with technique']


y_grd_sys_bacc = [bacc_avg_std_grd, bacc_avg_not_grd, bacc_avg_use_grd]
y_sud_sys_bacc = [bacc_avg_std_sud, bacc_avg_not_sud, bacc_avg_use_sud]
y_oc_sys_bacc = [bacc_avg_std_oc, bacc_avg_not_oc, bacc_avg_use_oc]

y_grd_sys_recall = [recall_avg_std_grd, recall_avg_not_grd, recall_avg_use_grd]
y_sud_sys_recall = [recall_avg_std_sud, recall_avg_not_sud, recall_avg_use_sud]
y_oc_sys_recall = [recall_avg_std_oc, recall_avg_not_oc, recall_avg_use_oc]


y_grd_sys_precision = [precision_avg_std_grd, precision_avg_not_grd, precision_avg_use_grd]
y_sud_sys_precision = [precision_avg_std_sud, precision_avg_not_sud, precision_avg_use_sud]
y_oc_sys_precision = [precision_avg_std_oc, precision_avg_not_oc, precision_avg_use_oc]


plt.figure(figsize=(19.5, 6.5))



plt.subplot(1,3,1)
plt.plot(x_sys_name , y_grd_sys_bacc , marker = 'o' , label = 'gradual' , color = 'hotpink')
plt.plot(x_sys_name , y_oc_sys_bacc , marker = 'o' , label = 're-occurring' , color = 'MidnightBlue')
plt.plot(x_sys_name , y_sud_sys_bacc , marker = 'o' , label = 'sudden' , color = 'DarkSeaGreen')


plt.xlabel("system type" , fontdict= font_lable)
plt.ylabel("avg bacc" , fontdict= font_lable)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.title("average bacc for 3 system types in 3 drifs" , fontdict=font_sub)
plt.legend(prop = font_props)


#..................................
plt.subplot(1,3,2)
plt.plot(x_sys_name , y_grd_sys_recall , marker = 'o' , label = 'gradual' , color = 'hotpink')
plt.plot(x_sys_name , y_oc_sys_recall , marker = 'o' , label = 're-occurring' , color = 'MidnightBlue')
plt.plot(x_sys_name , y_sud_sys_recall , marker = 'o' , label = 'sudden' , color = 'DarkSeaGreen')

plt.legend(prop = font_props)

plt.xlabel("system type" , fontdict= font_lable)
plt.ylabel("avg recall" , fontdict= font_lable)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.title("average recall for 3 system types in 3 drifs" , fontdict=font_sub)

#.................................

#...........................
plt.subplot(1,3,3)

plt.plot(x_sys_name , y_grd_sys_precision , marker = 'o' , label = 'gradual' , color = 'hotpink')
plt.plot(x_sys_name , y_oc_sys_precision , marker = 'o' , label = 're-occurring' , color = 'MidnightBlue')
plt.plot(x_sys_name , y_sud_sys_precision , marker = 'o' , label = 'sudden' , color = 'DarkSeaGreen')


plt.xlabel("system type" , fontdict= font_lable)
plt.ylabel("avg precision" , fontdict= font_lable)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.title("average precision for 3 system types in 3 drifs" , fontdict=font_sub)
plt.legend(prop = font_props)

#---------------------------------------------
plt.show()
